# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import pickle

# %%
info = pickle.load(open('~/rlplay/deep_rl_project/algos/data/info_1574741805_0433645', 'rb'))

iter_reward = [info[i][0] for i in range(len(info))]
avg_loss1 = [info[i][1] for i in range(len(info))]
avg_loss2 = [info[i][2] for i in range(len(info))]
avg_obj = [info[i][3] for i in range(len(info))]

# %%
plot_title = "TD3 Training"
data = [iter_reward, avg_loss1, avg_loss2, avg_obj]
sub_titles = ["Reward", "Q1 Function Loss", "Q2 Function Loss", "Policy Objective"]
x_labels = ["Iterations (200 steps)" for i in range(len(data))]
y_labels = ["Reward", "Q1 Loss", "Q2 Loss", "Objective"]

fig, axs = plt.subplots(1,len(data), figsize=(20,4))
fig.suptitle(plot_title)

axs = axs.flatten()
for i in range(len(data)):
    axs[i].set_title(sub_titles[i])
    axs[i].set_xlabel(x_labels[i])
    axs[i].set_ylabel(y_labels[i])
    axs[i].plot(range(len(data[i])), data[i])

# %%
info = pickle.load(open('/Users/duke/PycharmProjects/ECE276c/project4/policies/info_64_96024', 'rb'))

iter_reward = [info[i][0] for i in range(len(info))]
avg_loss = [info[i][1] for i in range(len(info))]
avg_obj = [info[i][2] for i in range(len(info))]

fig, axs = plt.subplots(1,len(data), figsize=(20,4))
fig.suptitle("DDPG Training")

data = [iter_reward, avg_loss, avg_obj]
titles = ["Reward", "Q Function Loss", "Policy Objective"]
x_labels = ["Iterations (200 steps)" for i in range(len(data))]
y_labels = ["Reward", "Loss", "Objective"]

axs = axs.flatten()
for i in range(len(data)):
    axs[i].set_title(titles[i])
    axs[i].set_xlabel(x_labels[i])
    axs[i].set_ylabel(y_labels[i])
    axs[i].plot(range(len(data[i])), data[i])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-1d28e48c7555> in <module>
# ----> 1 info = pickle.load(open('/Users/duke/PycharmProjects/ECE276c/project4/policies/info_64_96024', 'rb'))
#       2
#       3 iter_reward = [info[i][0] for i in range(len(info))]
#       4 avg_loss = [info[i][1] for i in range(len(info))]
#       5 avg_obj = [info[i][2] for i in range(len(info))]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/duke/PycharmProjects/ECE276c/project4/policies/info_64_96024'

# %%
info = pickle.load(open('/Users/duke/PycharmProjects/rlplay/deep_rl_project/data/info_1574741805_0433645', 'rb'))

iter_reward = [info[i][0] for i in range(len(info))]
avg_loss = [info[i][1] for i in range(len(info))]
avg_obj = [info[i][2] for i in range(len(info))]

data = [iter_reward, avg_loss, avg_obj]

fig, axs = plt.subplots(1,len(data), figsize=(20,4))
fig.suptitle("DDPG Training")
titles = ["Reward", "Q Function Loss", "Policy Objective"]
x_labels = ["Iterations (200 steps)" for i in range(len(data))]
y_labels = ["Reward", "Loss", "Objective"]

axs = axs.flatten()
for i in range(len(data)):
    axs[i].set_title(titles[i])
    axs[i].set_xlabel(x_labels[i])
    axs[i].set_ylabel(y_labels[i])
    axs[i].plot(range(len(data[i])), data[i])

# %%
import gym
env = gym.make("modified_gym_env:ReacherPyBulletEnv-v1", rand_init=True)
# Out:
# current_dir=/Users/duke/opt/anaconda3/envs/ece276c/lib/python3.7/site-packages/pybullet_envs/bullet

# %%
env.action_space.low
# Out:
# array([-1., -1.], dtype=float32)
